# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/learning-agency-lab-automated-essay-scoring-2/sample_submission.csv
# /kaggle/input/learning-agency-lab-automated-essay-scoring-2/train.csv
# /kaggle/input/learning-agency-lab-automated-essay-scoring-2/test.csv
# /kaggle/input/glove-6b-100d-txt/glove.6B.100d.txt

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, Bidirectional
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2024-04-28 08:49:02.343526: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-28 08:49:02.343647: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-28 08:49:02.492294: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
train = pd.read_csv('/kaggle/input/learning-agency-lab-automated-essay-scoring-2/train.csv')
test = pd.read_csv('/kaggle/input/learning-agency-lab-automated-essay-scoring-2/test.csv')
sub = pd.read_csv('/kaggle/input/learning-agency-lab-automated-essay-scoring-2/sample_submission.csv')
train
# Out:
#       essay_id                                          full_text  score
# 0      000d118  Many people have car where they live. The thin...      3
# 1      000fe60  I am a scientist at NASA that is discussing th...      3
# 2      001ab80  People always wish they had the same technolog...      4
# 3      001bdc0  We all heard about Venus, the planet without a...      4
# 4      002ba53  Dear, State Senator\n\nThis is a letter to arg...      3
# ...        ...                                                ...    ...
# 17302  ffd378d  the story " The Challenge of Exploing Venus " ...      2
# 17303  ffddf1f  Technology has changed a lot of ways that we l...      4
# 17304  fff016d  If you don't like sitting around all day than ...      2
# 17305  fffb49b  In "The Challenge of Exporing Venus," the auth...      1
# 17306  fffed3e  Venus is worthy place to study but dangerous. ...      2
#
# [17307 rows x 3 columns]

# %%
num_classes = len(train['score'].unique())
num_classes
# Out:
# 6

# %%
# !pip install -U -q sentencepiece

# %%
with open('./input.txt', 'w') as f:
    for line in train['full_text'].values:
        try:
            f.write(line)
        except:
            print("write error ---> ", line)

# %%
#write 가 잘 되었는지 확인
with open('./input.txt', 'r') as f:
    txt = f.read().split('\n')

print(len(txt))
print(txt[0])
# Out:
# 137259
# Many people have car where they live. The thing they don't know is that when you use a car alot of thing can happen like you can get in accidet or the smoke that the car has is bad to breath on if someone is walk but in VAUBAN,Germany they dont have that proble because 70 percent of vauban's families do not own cars,and 57 percent sold a car to move there. Street parkig ,driveways and home garages are forbidden on the outskirts of freiburd that near the French and Swiss borders. You probaly won't see a car in Vauban's streets because they are completely "car free" but If some that lives in VAUBAN that owns a car ownership is allowed,but there are only two places that you can park a large garages at the edge of the development,where a car owner buys a space but it not cheap to buy one they sell the space for you car for $40,000 along with a home. The vauban people completed this in 2006 ,they said that this an example of a growing trend in Europe,The untile states and some where else are suburban life from auto use this is called "smart planning". The current efforts to drastically reduce greenhouse gas emissions from tailes the passengee cars are responsible for 12 percent of greenhouse gas emissions in Europe and up to 50 percent in some car intensive in the United States. I honeslty think that good idea that they did that is Vaudan because that makes cities denser and better for walking and in VAUBAN there are 5,500 residents within a rectangular square mile. In the artical David Gold berg said that "All of our development since World war 2 has been centered on the cars,and that will have to change" and i think that was very true what David Gold said because alot thing we need cars to do we can go anyway were with out cars beacuse some people are a very lazy to walk to place thats why they alot of people use car and i think that it was a good idea that that they did that in VAUBAN so people can see how we really don't need car to go to place from place because we can walk from were we need to go or we can ride bycles with out the use of a car. It good that they are doing that if you thik about your help the earth in way and thats a very good thing to. In the United states ,the Environmental protection Agency is promoting what is called "car reduced"communtunties,and the legislators are starting to act,if cautiously. Maany experts expect pubic transport serving suburbs to play a much larger role in a new six years federal transportation bill to approved this year. In previous bill,80 percent of appropriations have by law gone to highways and only 20 percent to other transports. There many good reason why they should do this.    I am a scientist at NASA that is discussing the "face" on mars. I will be explaining how the "face" is a land form. By sharing my information about this isue i will tell you just that.

# %%
import sentencepiece as spm

spm.SentencePieceTrainer.Train('--input=input.txt --model_prefix=spm --vocab_size=10000')
sp = spm.SentencePieceProcessor()
sp.Load('{}.model'.format('spm'))
# Out:
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=input.txt --model_prefix=spm --vocab_size=10000
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: input.txt
#   input_format:
#   model_prefix: spm
#   model_type: UNIGRAM
#   vocab_size: 10000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differenti
# True
# al_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: input.txt
# trainer_interface.cc(380) LOG(WARNING) Found too long line (7759 > 4192).
# trainer_interface.cc(382) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(383) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(409) LOG(INFO) Loaded all 68585 sentences
# trainer_interface.cc(416) LOG(INFO) Skipped 47 too long sentences.
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=35292361
# trainer_interface.cc(550) LOG(INFO) Done: 99.9569% characters are covered.
# trainer_interface.cc(560) LOG(INFO) Alphabet size=68
# trainer_interface.cc(561) LOG(INFO) Final character coverage=0.999569
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 68585 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=19857451
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 162208 seed sentencepieces
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 68585
# trainer_interface.cc(609) LOG(INFO) Done! 132952
# unigram_model_trainer.cc(602) LOG(INFO) Using 132952 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=52174 obj=9.88571 num_tokens=294710 num_tokens/piece=5.6486
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=45012 obj=7.5763 num_tokens=296455 num_tokens/piece=6.58613
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=33754 obj=7.53956 num_tokens=306380 num_tokens/piece=9.07685
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=33734 obj=7.53393 num_tokens=306550 num_tokens/piece=9.08727
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=25300 obj=7.55557 num_tokens=324860 num_tokens/piece=12.8403
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=25300 obj=7.55129 num_tokens=324843 num_tokens/piece=12.8396
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=18975 obj=7.58364 num_tokens=345142 num_tokens/piece=18.1893
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=18975 obj=7.57741 num_tokens=345106 num_tokens/piece=18.1874
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=14231 obj=7.62103 num_tokens=366835 num_tokens/piece=25.7772
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=14231 obj=7.61302 num_tokens=366770 num_tokens/piece=25.7726
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=11000 obj=7.66678 num_tokens=387263 num_tokens/piece=35.2057
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=11000 obj=7.65751 num_tokens=387204 num_tokens/piece=35.2004
# trainer_interface.cc(687) LOG(INFO) Saving model: spm.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: spm.vocab

# %%
train_texts = [sp.encode_as_ids(t) for t in train['full_text'].values]
test_texts = [sp.encode_as_ids(t) for t in test['full_text'].values]

# %%
# 가장 긴 문장 길이 알아보기 (train과 test데이터 모두에서)
max([len(s) for s in train_texts] + [len(s) for s in test_texts]) #각각의 문장들의 길이를 쭈우욱 출력
# Out:
# 1824

# %%
# 히스토그램 빈도수
plt.hist([len(s) for s in train_texts] + [len(s) for s in test_texts], bins=50); #간격 조정 50

# %%
train_texts = pd.DataFrame(train_texts)
test_texts = pd.DataFrame(test_texts)

# %%
train_x, val_x, train_y, val_y = train_test_split(train_texts, train['score'], test_size = 0.2, random_state = 42)

print(train_x.shape)
print(val_x.shape)
print(train_y.shape)
print(val_y.shape)
# Out:
# (13845, 1824)
# (3462, 1824)
# (13845,)
# (3462,)

# %%
from tensorflow.keras.utils import to_categorical

train_y -= 1
val_y -= 1

# to_categorical 함수를 사용하여 원-핫 인코딩 적용
train_y = to_categorical(train_y, num_classes=num_classes)
val_y = to_categorical(val_y, num_classes=num_classes)

# %%
def make_embedding(num_words, embedding_dim, vocab_size):

    embeddings_dict = {}
    output = '/kaggle/input/glove-6b-100d-txt/glove.6B.100d.txt'
    
    with open(output, encoding="utf8") as f:
        for i, line in enumerate(f):
            values = line.split()            # 각 줄을 읽어와서 word_vector에 저장
            word = values[0]                 # 첫번째 값은 word
            # 두번째 element 부터 마지막까지 100 개는 해당 단어의 임베딩 벡터의  값
            coefs = np.asarray(values[1:], dtype='float32')  
            embeddings_dict[word] = coefs
                
    embedding_matrix = np.random.uniform(-0.25, 0.25, (num_words, embedding_dim))  # zero 로 초기화   
    
    print("word 갯수 =", num_words)
    print(embedding_matrix.shape)
    
    # SentencePiece 모델의 인덱스 정보 얻기
    #word_index = {word: sp.PieceToId(word) for word in sp}

    for i in range(vocab_size):  # SentencePiece 어휘집을 반복하면서
        word = sp.id_to_piece(i)
        embedding_vector = embeddings_dict.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
                    
    return embedding_matrix

# %%
vocab_size = 10000
EMBEDDING_DIM = 100
# create embedding matrix
embedding_matrix = make_embedding(vocab_size+1, EMBEDDING_DIM, 
                                vocab_size)
print(embedding_matrix.shape, type(embedding_matrix))
# Out:
# word 갯수 = 10001
# (10001, 100)
# (10001, 100) <class 'numpy.ndarray'>

# %%
import keras
print(keras.__version__)
# Out:
# 3.2.1

# %%
# input layer
inputs = Input(shape=(None,))

# Embedding layer 
embedding_layer = Embedding(vocab_size+1, EMBEDDING_DIM, trainable=True)
embedding_layer.build((None,))
embedding_layer.set_weights([embedding_matrix])

dropout_emb = Dropout(0.2)(embedding_layer(inputs))
lstm = Bidirectional(LSTM(100))(dropout_emb)
dropout_lstm = Dropout(0.2)(lstm)
dense_layer1 = Dense(64, activation='relu')(dropout_lstm)
dropout_dense = Dropout(0.2)(dense_layer1)

# output layer
outputs = Dense(num_classes, activation='softmax')(dropout_dense)

model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=Adam(0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, None)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_1 (Embedding)         │ (None, None, 100)      │     1,000,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, None, 100)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 200)            │       160,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        12,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,174,154 (4.48 MB)
#  Trainable params: 1,174,154 (4.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# %%time
num_epochs = 60
history = model.fit(train_x, train_y, epochs=num_epochs, batch_size=512,
                validation_data=(val_x, val_y), verbose=1)
# Out:
# Epoch 1/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 577ms/step - accuracy: 0.1435 - loss: 1.7621 - val_accuracy: 0.3654 - val_loss: 1.6025
# Epoch 2/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.3532 - loss: 1.5716 - val_accuracy: 0.3654 - val_loss: 1.4786
# Epoch 3/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.3399 - loss: 1.4905 - val_accuracy: 0.3654 - val_loss: 1.4622
# Epoch 4/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.3415 - loss: 1.4732 - val_accuracy: 0.3654 - val_loss: 1.4592
# Epoch 5/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.3296 - loss: 1.4862 - val_accuracy: 0.3654 - val_loss: 1.4573
# Epoch 6/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 562ms/step - accuracy: 0.3508 - loss: 1.4699 - val_accuracy: 0.3654 - val_loss: 1.4548
# Epoch 7/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.3473 - loss: 1.4722 - val_accuracy: 0.3654 - val_loss: 1.4515
# Epoch 8/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 561ms/step - accuracy: 0.3481 - loss: 1.4646 - val_accuracy: 0.3654 - val_loss: 1.4473
# Epoch 9/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.3464 - loss: 1.4629 - val_accuracy: 0.3674 - val_loss: 1.4395
# Epoch 10/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 561ms/step - accuracy: 0.3475 - loss: 1.4561 - val_accuracy: 0.3723 - val_loss: 1.4216
# Epoch 11/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 561ms/step - accuracy: 0.3599 - loss: 1.4404 - val_accuracy: 0.4055 - val_loss: 1.3904
# Epoch 12/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 561ms/step - accuracy: 0.3743 - loss: 1.4141 - val_accuracy: 0.4217 - val_loss: 1.3728
# Epoch 13/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.3940 - loss: 1.3770 - val_accuracy: 0.4018 - val_loss: 1.3927
# Epoch 14/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.4187 - loss: 1.3483 - val_accuracy: 0.4281 - val_loss: 1.3602
# Epoch 15/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.4185 - loss: 1.3155 - val_accuracy: 0.4760 - val_loss: 1.2589
# Epoch 16/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.4498 - loss: 1.2612 - val_accuracy: 0.4417 - val_loss: 1.2369
# Epoch 17/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.4536 - loss: 1.2426 - val_accuracy: 0.4798 - val_loss: 1.1897
# Epoch 18/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.4607 - loss: 1.2234 - val_accuracy: 0.4795 - val_loss: 1.1637
# Epoch 19/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 564ms/step - accuracy: 0.4825 - loss: 1.1945 - val_accuracy: 0.5101 - val_loss: 1.1328
# Epoch 20/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5242 - loss: 1.1310 - val_accuracy: 0.5479 - val_loss: 1.0900
# Epoch 21/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5230 - loss: 1.1230 - val_accuracy: 0.5569 - val_loss: 1.0797
# Epoch 22/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5337 - loss: 1.1036 - val_accuracy: 0.5335 - val_loss: 1.1365
# Epoch 23/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5521 - loss: 1.0649 - val_accuracy: 0.5442 - val_loss: 1.1063
# Epoch 24/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5469 - loss: 1.0669 - val_accuracy: 0.5748 - val_loss: 1.0191
# Epoch 25/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5686 - loss: 1.0433 - val_accuracy: 0.5760 - val_loss: 1.0345
# Epoch 26/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5709 - loss: 1.0418 - val_accuracy: 0.5581 - val_loss: 1.0589
# Epoch 27/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5739 - loss: 1.0252 - val_accuracy: 0.5731 - val_loss: 1.0186
# Epoch 28/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5802 - loss: 1.0112 - val_accuracy: 0.5838 - val_loss: 0.9889
# Epoch 29/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5740 - loss: 1.0051 - val_accuracy: 0.5032 - val_loss: 1.1755
# Epoch 30/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5698 - loss: 1.0215 - val_accuracy: 0.5734 - val_loss: 0.9813
# Epoch 31/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 563ms/step - accuracy: 0.5794 - loss: 0.9867 - val_accuracy: 0.5711 - val_loss: 1.0343
# Epoch 32/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5747 - loss: 1.0186 - val_accuracy: 0.5269 - val_loss: 1.1020
# Epoch 33/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5803 - loss: 0.9995 - val_accuracy: 0.5936 - val_loss: 0.9651
# Epoch 34/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6021 - loss: 0.9561 - val_accuracy: 0.5650 - val_loss: 1.0190
# Epoch 35/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6001 - loss: 0.9431 - val_accuracy: 0.5638 - val_loss: 1.0541
# Epoch 36/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5890 - loss: 0.9731 - val_accuracy: 0.5713 - val_loss: 1.0738
# Epoch 37/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5983 - loss: 0.9778 - val_accuracy: 0.5956 - val_loss: 0.9692
# Epoch 38/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5997 - loss: 0.9597 - val_accuracy: 0.5898 - val_loss: 0.9492
# Epoch 39/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 564ms/step - accuracy: 0.5931 - loss: 0.9627 - val_accuracy: 0.5699 - val_loss: 1.0253
# Epoch 40/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6016 - loss: 0.9458 - val_accuracy: 0.5191 - val_loss: 1.1934
# Epoch 41/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.5494 - loss: 1.0779 - val_accuracy: 0.5913 - val_loss: 0.9871
# Epoch 42/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6175 - loss: 0.9181 - val_accuracy: 0.5898 - val_loss: 1.0023
# Epoch 43/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6224 - loss: 0.9244 - val_accuracy: 0.5676 - val_loss: 1.0404
# Epoch 44/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6184 - loss: 0.9085 - val_accuracy: 0.5945 - val_loss: 0.9483
# Epoch 45/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6338 - loss: 0.8941 - val_accuracy: 0.5991 - val_loss: 0.9302
# Epoch 46/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6301 - loss: 0.8977 - val_accuracy: 0.5737 - val_loss: 0.9925
# Epoch 47/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.6317 - loss: 0.8847 - val_accuracy: 0.6011 - val_loss: 0.9287
# Epoch 48/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.6369 - loss: 0.8807 - val_accuracy: 0.6046 - val_loss: 0.9538
# Epoch 49/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6399 - loss: 0.8674 - val_accuracy: 0.5936 - val_loss: 0.9461
# Epoch 50/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6307 - loss: 0.8793 - val_accuracy: 0.5676 - val_loss: 1.0199
# Epoch 51/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6092 - loss: 0.9047 - val_accuracy: 0.5809 - val_loss: 0.9911
# Epoch 52/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6388 - loss: 0.8604 - val_accuracy: 0.6040 - val_loss: 0.9215
# Epoch 53/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.6175 - loss: 0.8962 - val_accuracy: 0.5971 - val_loss: 0.9586
# Epoch 54/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6360 - loss: 0.8764 - val_accuracy: 0.5930 - val_loss: 0.9472
# Epoch 55/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.6034 - loss: 0.9248 - val_accuracy: 0.5875 - val_loss: 0.9747
# Epoch 56/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.6375 - loss: 0.8599 - val_accuracy: 0.5661 - val_loss: 1.0341
# Epoch 57/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6428 - loss: 0.8597 - val_accuracy: 0.6092 - val_loss: 0.9163
# Epoch 58/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.6487 - loss: 0.8417 - val_accuracy: 0.6028 - val_loss: 0.9311
# Epoch 59/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.6599 - loss: 0.8342 - val_accuracy: 0.6020 - val_loss: 0.9344
# Epoch 60/60
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 562ms/step - accuracy: 0.6228 - loss: 0.8869 - val_accuracy: 0.6005 - val_loss: 0.9252
# CPU times: user 11min 40s, sys: 3min 1s, total: 14min 42s
# Wall time: 15min 59s

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4)) #ax1, ax2 두개의 축

ax1.plot(history.history['accuracy'], label = 'accuracy')
ax1.plot(history.history['val_accuracy'], label = 'val_accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('accuracy')
ax1.legend(['accuarcy', 'val_accuracy'])

ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_xlabel('Epochs')
ax2.set_ylabel('loss')
ax2.legend(['loss', 'val_loss'])
plt.show()

# %%
result = model.predict(test_texts)
print(result)
print(result.argmax(1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# [[3.1029567e-02 6.4467549e-01 3.1514689e-01 8.2347114e-03 6.5301068e-04
#   2.6029872e-04]
#  [6.3395961e-03 2.3956040e-01 7.2268575e-01 3.0269794e-02 9.0936583e-04
#   2.3505763e-04]
#  [5.4374565e-03 1.3194623e-02 1.3101085e-01 5.2778417e-01 2.8373700e-01
#   3.8835920e-02]]
# [1 2 3]

# %%
sub['score'] = result.argmax(1)
sub['score'] += 1
sub.to_csv('submission.csv', index = False)
